# %% [markdown]
# # Imports:

# %%
import numpy as np
import gwinc  # Import the gwinc package for gravitational wave interferometer noise curves
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scienceplots
from cycler import cycler
plt.style.use(['science','ieee','notebook'])
plt.rcParams.update({'figure.dpi': 300})
plt.rcParams['axes.prop_cycle'] = cycler('color', ['#1F77B4', '#FF7F0E', '#2CA02C', '#D62728', '#9467BD', '#8C564B', '#E377C2', '#7F7F7F', '#BCBD22', '#17BECF', '#9A0EEA'])
plt.rcParams.update({'font.serif': 'serif', 'font.family' : 'DeJavu Serif'})
plt.rcParams.update({
        'font.size': 21,
        'axes.labelsize': 21,
        'xtick.labelsize': 18,
        'ytick.labelsize': 18,
        'legend.fontsize': 16
    })

# %% [markdown]
# # Graphing Code:

# %%
def plot_LIGO(y_data_list, rangE, freq, label_list):
    # Plot the ASDs by looping through the input NSR list and plotting every array value
    plt.figure(figsize=(10, 8))
    plt.loglog(freq, y_data_list[0], '--', label= label_list[0], color = colors[0])
    i=1 #=0
    while i< len(y_data_list) - 1:
        plt.loglog(freq, y_data_list[i], label= label_list[i], color = colors[i])
        i+=1
    # plt.loglog(freq, y_data_list[-1], '--', label= label_list[-1], color = colors[i])
    plt.loglog(freq, y_data_list[-1], label= label_list[-1], color='black')
    plt.grid(True, which='major', linestyle='-', linewidth=0.75)
    plt.grid(False, which='minor')  # Disable grid lines for minor ticks
    plt.xlabel('Frequency (Hz)')
    plt.ylabel(r'ASD ($1/\sqrt{\text{Hz}}$)')
    plt.ylim(1e-24, 1e-19)
    plt.xlim(1e1, 1e5)
    plt.legend(frameon=True, ncols=2, loc='upper left', title='GEO600 detuning angles') #aLIGO detuning angles
    plt.tick_params(which='both',  direction = 'out', top=False, left=True, right=False, bottom=True)
    # plt.savefig('Detuning GEO600.pdf',format='pdf', dpi=300) #Detuning aLIGO
    plt.show()
    
    return

# %% [markdown]
# # aLIGO Detuning Code:

# %%
def detuneLIGO(rangee, budget, frequencies, label, y_data_list, F_norm):
    initial_power = budget.ifo.Laser.Power
    for i in rangee:
        budget.ifo.update({
            'Optics.SRM.Tunephase': i*np.pi/180,
        })
        trace = budget.run()
        fig = trace.plot()
        ax = fig.axes[0]
        plt.close(fig)
        first_line = ax.get_lines()[0]
        y1_data = first_line.get_ydata()/F_norm
        y_data_list.append(y1_data)
        label.append(f'$\phi$={(i-180)//2}')
        
        
    return y_data_list, label

# %% [markdown]
# # Initialize Inputs and Obtain ASD Curves:

# %%
# Now detuning aLIGO/GEO600 and seeing the affect on the actual strain ASD
freq = np.logspace(0, 5, 100000)
budget = gwinc.load_budget('aLIGO', freq=freq)

# aLIGO PyGWINC detuning angles: [182,210,240,270,300,330,360] # excluding 0 - not physically representable
# GEO600 Finesse detuning angles: [15,30,45,60,75,90] # excluding 0 (tuned) - manually added to asd array before for loop
# GEO600 Finesse detuning angles = (PyGWINC detuning angle - 180) / 2
rangE = [15,30,45,60,75,90]
y_data_list = []
label = []
colors = ['midnightblue', '#1F77B4', '#FF7F0E', '#2CA02C', '#D62728', '#9467BD', '#8C564B', '#E377C2', '#7F7F7F', '#BCBD22', '#17BECF', '#9A0EEA']


# Load in the antenna pattern array for aLIGO and GEO (already implemented in GEO600 arrays when created, so load them in to cancel the sky-averaging out):
with np.load('Antenna Patterns/GEO_F_rms_100000_05.npz') as data:
        F_GEO_rms = data['F_rms']
with np.load('Antenna Patterns/GEO_F_15_100000_05.npz') as data:
        F_GEO_15 = data['F_15']
with np.load('Antenna Patterns/LIGO_F_15_100000_05.npz') as data:
        F_LIGO_15 = data['F_15']
        

with np.load('ASD_50W_100000_05.npz') as data:
    asd_array2 = data[f'GEO600']*F_GEO_rms/F_GEO_15
    label.append('Tuned')
    y_data_list.append(asd_array2)
    for phi in rangE:
        asd_array = data[f'GEO600_{phi}']*F_GEO_rms/F_GEO_15
        y_data_list.append(asd_array)
        label.append(f'$\phi$={phi}')
    asd_array3 = data[f'GEO600 Scanned']*F_GEO_rms/F_GEO_15
    label.append('Scanned')
    y_data_list.append(asd_array3)


# y_data_list, label = detuneLIGO(rangE, budget, freq, label, y_data_list, F_LIGO_15)
# label.pop(-1)
# label.append('Tuned')

# %% [markdown]
# # Plot Results:

# %%
plot_LIGO(y_data_list, rangE, freq, label)
